# %% [markdown]
# # Makine Öğrenmesi Bitirme Projesi;

# %% [markdown]
# ## Titanic Veriseti ve Keşfi

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
"""
Veri setimiz tarihin en büyük gemi kazalarından biri olan batmaz denilen Titanic gemisine aittir.
Yolcuların ID numarası,Yaşayıp yaşamama durumu,Bilet sınıfı,İsmi,Cinsiyeti,Yaşı,Gemide yer alan tanıdık(eş) sayısı,
Gemide yer alan ebeveyn / çocuk sayısı,Bilet numarası,Yolcu ücreti,Bindiği kabin ve gemiye bindiği şehir yer almaktadır.
"""
# Out:
# '\nVeri setimiz tarihin en büyük gemi kazalarından biri olan batmaz denilen Titanic gemisine aittir.\nYolcuların ID numarası,Yaşayıp yaşamama durumu,Bilet sınıfı,İsmi,Cinsiyeti,Yaşı,Gemide yer alan tanıdık(eş) sayısı,\nGemide yer alan ebeveyn / çocuk sayısı,Bilet numarası,Yolcu ücreti,Bindiği kabin ve gemiye bindiği şehir yer almaktadır.\n'

# %%
data=pd.read_csv("titanic.csv") 
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.shape
# Out:
# (891, 12)

# %%
def uniquedegerler(columns,df=data):
    
    deger = len(df[columns].unique())
    print(df[columns].unique())
    return print("{} eşsiz değer sayısı : {}".format(columns,deger))

# %%
uniquedegerler("Embarked")
# Out:
# ['S' 'C' 'Q' nan]
# Embarked eşsiz değer sayısı : 4

# %%
uniquedegerler("Age")
# Out:
# [22.   38.   26.   35.     nan 54.    2.   27.   14.    4.   58.   20.
#  39.   55.   31.   34.   15.   28.    8.   19.   40.   66.   42.   21.
#  18.    3.    7.   49.   29.   65.   28.5   5.   11.   45.   17.   32.
#  16.   25.    0.83 30.   33.   23.   24.   46.   59.   71.   37.   47.
#  14.5  70.5  32.5  12.    9.   36.5  51.   55.5  40.5  44.    1.   61.
#  56.   50.   36.   45.5  20.5  62.   41.   52.   63.   23.5   0.92 43.
#  60.   10.   64.   13.   48.    0.75 53.   57.   80.   70.   24.5   6.
#   0.67 30.5   0.42 34.5  74.  ]
# Age eşsiz değer sayısı : 89

# %%
data["Embarked"].value_counts().plot.pie(legend=True,autopct="%1.2f%%")
# Out:
# <AxesSubplot:ylabel='Embarked'>

# %%
data["Sex"].value_counts().plot.pie(legend=True,autopct="%1.2f%%")
# Out:
# <AxesSubplot:ylabel='Sex'>

# %%
data["Survived"].value_counts().plot.pie(legend=True,autopct="%1.2f%%")
# Out:
# <AxesSubplot:ylabel='Survived'>

# %%
data["Pclass"].value_counts().plot.pie(legend=True,autopct="%1.2f%%")
# Out:
# <AxesSubplot:ylabel='Pclass'>

# %%
sns.barplot(x="Pclass",y="Fare", data=data);

# %%
sns.barplot(x="Embarked",y="Fare", data=data);

# %%
sns.barplot(x="Embarked",y="Survived",hue="Sex", data=data);

# %%
sns.countplot(data.Embarked);
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(data.Survived);
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize = (9,3))
plt.hist(data["Age"], bins = 50)
plt.xlabel("Age")
plt.show()

# %%
sns.boxplot(data=data, x="Age")
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
sns.boxplot(data=data, x="Fare")
# Out:
# <AxesSubplot:xlabel='Fare'>

# %%
plt.figure()
sns.countplot(x='Sex',hue='Survived', data=data)
plt.show()

# %%
plt.figure()
sns.countplot(x='Embarked',hue='Survived', data=data)
plt.show()

# %% [markdown]
# ## Titanic Veriseti Temizleme

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data['Age'].fillna(data['Age'].median(), inplace=True)

# %%
data['Age'].isnull().sum()
# Out:
# 0

# %%
data.drop('Cabin',axis=1,inplace=True)

# %%
data.info() #Verimize tekrardan göz atıyoruz.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
data["Embarked"].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
data.Embarked.fillna("S",inplace=True)

# %%
data['Embarked'].isnull().sum()
# Out:
# 0

# %%
data.isnull().sum().any()
# Out:
# False

# %%
data.duplicated(subset=['Name']).any()
# Out:
# False

# %%
data.duplicated().any()
# Out:
# False

# %%
from helpers.data_prep import *

# %%
sns.boxplot(data=data, x="Age")
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
data["Age"].max()
# Out:
# 80.0

# %%
outlier_thresholds(data,"Age")
# Out:
# (-66.0, 126.0)

# %%
check_outlier(data,"Age")
# Out:
# False

# %%
outlier_thresholds(data,"Fare")
# Out:
# (-150.056225, 269.360375)

# %%
sns.boxplot(data=data, x="Fare")
# Out:
# <AxesSubplot:xlabel='Fare'>

# %%
check_outlier(data,"Fare")
# Out:
# True

# %%
def replace_with_thresholds(dataframe, variable, q1=0.05, q3=0.95):
    low_limit, up_limit = outlier_thresholds(dataframe, variable, q1, q3)
    dataframe.loc[(dataframe[variable] > up_limit), variable] = up_limit
    dataframe.loc[(dataframe[variable] < low_limit), variable] = low_limit

# %%
replace_with_thresholds(data,'Fare')

# %%
check_outlier(data,"Fare")
# Out:
# False

# %%
sns.boxplot(data=data, x="Fare")
# Out:
# <AxesSubplot:xlabel='Fare'>

# %% [markdown]
# ## Titanic Future Engineering

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(data.corr(method="pearson"), vmin=-1, vmax=1, annot=True)
plt.title("Titanic Korelasyon")
plt.show()

# %%
df2 = pd.get_dummies(data.Sex) #(kukla değişken)
data = pd.concat([data, df2],axis='columns')
data.drop('Sex', axis='columns', inplace=True)
data.head(3)
# Out:
#    PassengerId  Survived  Pclass                                               Name    Age  SibSp  Parch            Ticket   Fare Embarked  female  male
# 0            1         0       3                            Braund, Mr. Owen Harris 22.000      1      0         A/5 21171  7.250        S       0     1
# 1            2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th... 38.000      1      0          PC 17599 71.283        C       1     0
# 2            3         1       3                             Heikkinen, Miss. Laina 26.000      0      0  STON/O2. 3101282  7.925        S       1     0

# %%
df3 = pd.get_dummies(data.Embarked)
data = pd.concat([data, df3],axis='columns')
data.drop('Embarked', axis='columns', inplace=True)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass                                               Name    Age  SibSp  Parch            Ticket   Fare  female  male  C  Q  S
# 0            1         0       3                            Braund, Mr. Owen Harris 22.000      1      0         A/5 21171  7.250       0     1  0  0  1
# 1            2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th... 38.000      1      0          PC 17599 71.283       1     0  1  0  0
# 2            3         1       3                             Heikkinen, Miss. Laina 26.000      0      0  STON/O2. 3101282  7.925       1     0  0  0  1
# 3            4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel) 35.000      1      0            113803 53.100       1     0  0  0  1
# 4            5         0       3                           Allen, Mr. William Henry 35.000      0      0            373450  8.050       0     1  0  0  1

# %%
data.drop('Name',axis=1,inplace=True)
data.drop('Ticket',axis=1,inplace=True)

# %%
data.drop('PassengerId',axis=1,inplace=True)

# %%
data.head(10)
# Out:
#    Survived  Pclass    Age  SibSp  Parch            Ticket   Fare  female  male  C  Q  S
# 0         0       3 22.000      1      0         A/5 21171  7.250       0     1  0  0  1
# 1         1       1 38.000      1      0          PC 17599 71.283       1     0  1  0  0
# 2         1       3 26.000      0      0  STON/O2. 3101282  7.925       1     0  0  0  1
# 3         1       1 35.000      1      0            113803 53.100       1     0  0  0  1
# 4         0       3 35.000      0      0            373450  8.050       0     1  0  0  1
# 5         0       3 28.000      0      0            330877  8.458       0     1  0  1  0
# 6         0       1 54.000      0      0             17463 51.862       0     1  0  0  1
# 7         0       3  2.000      3      1            349909 21.075       0     1  0  0  1
# 8         1       3 27.000      0      2            347742 11.133       1     0  0  0  1
# ...

# %%
# Makine öğreniminde işimize yaramıcak sütünları siliyoruz.

# %% [markdown]
# ## Titanic Model Geliştirme

# %%
kolon = data[['Pclass',"female","male","C","Q","S",'Age','Fare']]
kolon.head(2)
# Out:
#    Pclass  female  male  C  Q  S    Age   Fare
# 0       3       0     1  0  0  1 22.000  7.250
# 1       1       1     0  1  0  0 38.000 65.634

# %%
target=data["Survived"]
target.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn import metrics

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.neighbors import KNeighborsClassifier

# %%
x_train, x_test, y_train, y_test = train_test_split(kolon,target,test_size=0.2,random_state=0) #Modelimizi test ve eğitim olmak üzere 2 parçaya bölüyoruz. 
# %80 eğitim %20 test

# %% [markdown]
# ### Karar Ağacı

# %% [markdown]
# ![image.png](attachment:image.png)
# Karar ağacı, çok sayıda kayıt içeren bir veri kümesini, bir dizi karar kuralları uygulayarak daha küçük kümelere bölmek için kullanılan bir yapıdır. Yani basit karar verme adımları uygulanarak, büyük miktarlardaki kayıtları, çok küçük kayıt gruplarına bölerek kullanılan bir yapıdır.

# %%
model_tree = DecisionTreeClassifier()

# %%
sc = StandardScaler()
sc.fit(x_train)
x_train_std = sc.transform(x_train)
x_test_std = sc.transform(x_test)
model_tree.fit(x_train_std, y_train )
# Out:
# DecisionTreeClassifier()

# %%
model_tree.score(x_test_std, y_test )
# Out:
# 0.7988826815642458

# %%
Y_pred=model_tree.predict(x_test_std)

# %%
cm = confusion_matrix(y_test, Y_pred)
print(cm)
print("Accuracy:", accuracy_score(y_test, Y_pred))
print(classification_report(y_test, Y_pred))
# Out:
# [[95 15]
#  [21 48]]
# Accuracy: 0.7988826815642458
#               precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84       110
#            1       0.76      0.70      0.73        69
#
#     accuracy                           0.80       179
#    macro avg       0.79      0.78      0.78       179
# weighted avg       0.80      0.80      0.80       179

# %%
fpr,tpr,threshold=metrics.roc_curve(y_test, Y_pred)
roc_auc=metrics.auc(fpr,tpr)
plt.plot(fpr,tpr,"b",label="AUC : %0.2f" % roc_auc)
plt.title("ROC EĞRİSİ")
plt.legend(loc="lower right")
plt.plot([0,1],[0,1],"r--")
plt.xlim([0,1])
plt.ylim([0,1])
plt.ylabel("True Positive Rate")
plt.xlabel("False Positive Rate")
plt.show()

# %% [markdown]
# ###  LogisticRegression

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# Doğrusal sınıflandırma problemlerinde yaygın bir biçimde kullanılır. Regresyon denilmesine rağmen burada bir sınıflandırma söz konusudur.
# Lojistik regresyon, bir sonucu belirleyen bir veya daha fazla bağımsız değişken bulunan bir veri kümesini analiz etmek için kullanılan istatistiksel bir yöntemdir.

# %%
from sklearn.preprocessing import StandardScaler

# %%
lregresyon = LogisticRegression()
sc = StandardScaler()
sc.fit(x_train)
x_train_std = sc.transform(x_train)
x_test_std = sc.transform(x_test)

# %%
lregresyon = LogisticRegression()
lregresyon.fit(x_train_std, y_train)
# Out:
# LogisticRegression()

# %%
ypred = lregresyon.predict(x_test_std)

print(classification_report(y_test, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83       110
#            1       0.73      0.74      0.73        69
#
#     accuracy                           0.79       179
#    macro avg       0.78      0.78      0.78       179
# weighted avg       0.79      0.79      0.79       179

# %%
cm = confusion_matrix(y_test, ypred)
print(cm)
print("Accuracy:", accuracy_score(y_test, ypred))
# Out:
# [[91 19]
#  [18 51]]
# Accuracy: 0.7932960893854749

# %%
fpr,tpr,threshold=metrics.roc_curve(y_test, ypred)
roc_auc=metrics.auc(fpr,tpr)
plt.plot(fpr,tpr,"b",label="AUC : %0.2f" % roc_auc)
plt.title("ROC EĞRİSİ")
plt.legend(loc="lower right")
plt.plot([0,1],[0,1],"r--")
plt.xlim([0,1])
plt.ylim([0,1])
plt.ylabel("True Positive Rate")
plt.xlabel("False Positive Rate")
plt.show()

# %% [markdown]
# ### Random Forest

# %% [markdown]
# ![image.png](attachment:image.png)
# Random forest, birden fazla karar ağacını kullanarak daha uyumlu modeller üreterek daha isabetli sınıflandırma yapmaya çalışan bir sınıflandırma modelidir.
# Rastgele ormanlar, çok az yapılandırma gerektirirken geniş bir veri yelpazesinde makul tahminler ürettikleri için işletmelerde sıklıkla "kara kutu" modelleri olarak kullanılır.

# %%
rfc = RandomForestClassifier(max_depth=6, max_features=7)
rfc.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=6, max_features=7)

# %%
ypred = rfc.predict(x_test)
cm = confusion_matrix(y_test, Y_pred)
print(cm)
print(classification_report(y_test, ypred))
print(round(rfc.score(x_train, y_train) * 100, 2))
print("Accuracy:", accuracy_score(y_test, ypred))
# Out:
# [[101   9]
#  [ 20  49]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.95      0.88       110
#            1       0.90      0.65      0.76        69
#
#     accuracy                           0.84       179
#    macro avg       0.86      0.80      0.82       179
# weighted avg       0.85      0.84      0.83       179
#
# 88.48
# Accuracy: 0.8379888268156425

# %%
fpr,tpr,threshold=metrics.roc_curve(y_test, ypred)
roc_auc=metrics.auc(fpr,tpr)
plt.plot(fpr,tpr,"b",label="AUC : %0.2f" % roc_auc)
plt.title("ROC EĞRİSİ")
plt.legend(loc="lower right")
plt.plot([0,1],[0,1],"r--")
plt.xlim([0,1])
plt.ylim([0,1])
plt.ylabel("True Positive Rate")
plt.xlabel("False Positive Rate")
plt.show()

# %% [markdown]
# Random Forest modelinde FP değeri Lojistik regresyona göre daha fazla bu da demek oluyor ki lojistik regresyona göre daha fazla yanlışa doğru demişiz. Ayrıca denediğim modeller arasında FP değeri en güçlü olan model Lojistik regresyon

# %% [markdown]
# ### KNN

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# KNN en basit anlamı ile içerisinde tahmin edilecek değerin bağımsız değişkenlerinin oluşturduğu vektörün en yakın komşularının hangi sınıfta yoğun olduğu bilgisi üzerinden sınıfını tahmin etmeye dayanır.

# %%
sc = StandardScaler()
sc.fit(x_train)
x_train_std = sc.transform(x_train)
x_test_std = sc.transform(x_test)

# %%
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(x_train_std, y_train)
Y_pred = knn.predict(x_test_std)
cm = confusion_matrix(y_test, Y_pred)
print(cm)
print(classification_report(y_test, Y_pred))
print("Accuracy:", accuracy_score(y_test, Y_pred))
# Out:
# [[101   9]
#  [ 20  49]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.92      0.87       110
#            1       0.84      0.71      0.77        69
#
#     accuracy                           0.84       179
#    macro avg       0.84      0.81      0.82       179
# weighted avg       0.84      0.84      0.83       179
#
# Accuracy: 0.8379888268156425

# %%
fpr,tpr,threshold=metrics.roc_curve(y_test, Y_pred)
roc_auc=metrics.auc(fpr,tpr)
plt.plot(fpr,tpr,"b",label="AUC : %0.2f" % roc_auc)
plt.title("ROC EĞRİSİ")
plt.legend(loc="lower right")
plt.plot([0,1],[0,1],"r--")
plt.xlim([0,1])
plt.ylim([0,1])
plt.ylabel("True Positive Rate")
plt.xlabel("False Positive Rate")
plt.show()

# %% [markdown]
# Meriç Üren
